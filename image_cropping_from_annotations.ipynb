# %%
import os, sys
import glob
import h5py
import shutil
import imgaug as aug
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import imgaug.augmenters as iaa
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize


color = sns.color_palette()
# %matplotlib inline
           
from google.colab import drive
drive.mount('/content/drive')

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory


import cv2 as cv
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image
import ast
import os
import cv2
import os
import glob
import xml.etree.ElementTree as ET

original_file ='/content/drive/MyDrive/computer_vision_exam/frame400-599_Brian/' #you images directory
dst ='/content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/'

def check_folder_exists(path):
        if not os.path.exists(path):
            try:
                os.makedirs(path)
                print ('create ' + path)
            except OSError as e:
                if e.errno != errno.EEXIST:
                    raise




seed_arr = []
for xml_file in glob.glob('/content/drive/MyDrive/computer_vision_exam/annotated/Annotations/task_crops annotation-2022_09_28_12_33_04-pascal voc 1.1/Annotations/*.xml'): #your xml directory 
    root = ET.parse(xml_file).getroot()
    filename = root.find('filename').text

    for type_tag in root.findall('size'):
        #file_name = type_tag.find('filename').text
        width = type_tag.find('width').text
        height = type_tag.find('height').text

    for type_tag in root.findall('object'):
        class_name = type_tag.find('name').text
        xmin = type_tag.find('bndbox/xmin').text
        ymin = type_tag.find('bndbox/ymin').text
        xmax = type_tag.find('bndbox/xmax').text
        ymax = type_tag.find('bndbox/ymax').text
        all_list = [filename, width,height,class_name,xmin, ymin, xmax,ymax]

        seed_arr.append(all_list)
    
seed_arr.sort()
#print(str(len(seed_arr)))
#print(str(seed_arr))


for index, line in enumerate(seed_arr):
    filename = line[0]
    width = line[1]
    height = line[2]
    class_name = line[3]
    xmin = line[4]
    ymin = line[5]
    xmax = line[6]
    ymax = line[7]
    

#print(len(class_name))
    

    
    load_img_path = os.path.join(original_file, filename)
    #save img path

#save img path----------
    save_class_path = os.path.join(dst, class_name)
    check_folder_exists(save_class_path)
    save_img_path = os.path.join(save_class_path, str(index)+'_'+filename)
    
    img = Image.open(load_img_path)
    crop_img = img.crop((float(xmin) ,float(ymin) ,float(xmax) ,float(ymax)))
    newsize = (224, 224) 
    im1 = crop_img.resize(newsize) 
    im1.save(save_img_path, 'JPEG')
    print('save ' + save_img_path)
# Out:
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Bananas/0_frame400.jpg
# create /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/1_frame400.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/2_frame400.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/3_frame400.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/4_frame400.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Bananas/5_frame401.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/6_frame401.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/7_frame401.jpg
# save /content/drive/MyDrive/computer_vision_exam/annotated/cropped_images/Cassava/8_frame401.jpg
# ...

# %%
# # cropped_image = image_array[1300:2300,1000:2000] # Using array slicing we cut some part of the image and save in a new variable

# files=listdir('/content/drive/MyDrive/computer_vision_exam/frame400-599_Brian') #Importing the dir for cropping
# for file in files:
#     img = cv.imread('/content/drive/MyDrive/computer_vision_exam/frame400-599_Brian/'+file) # reading a single image from the dir
#     crop_img = img[1300:2300,1000:2000]
#     cv.imwrite('/content/drive/MyDrive/computer_vision_exam/cropped/bananas'+file,crop_img) # write new data to img
